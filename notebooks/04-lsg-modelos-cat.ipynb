# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Importação de bibliotecas

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %% [markdown]
# ### Variáveis categóricas

# %%
# Variáveis categóricas
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"] # Coluna categórica que não está ordenada

coluna_ordinal_encoder = ["median_income_cat"] # Coluna categorica que já está ordenada

# %%
preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder), # Coluna categorica que já está ordenada
        ("one_hot_encoder", OneHotEncoder(), coluna_one_hot_encoder), # Coluna categórica que não está ordenada
    ],
    remainder="passthrough",
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
target_transformer = PowerTransformer()

regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor       0.0   0.008004 -0.000081
# 1            DummyRegressor  0.004892   0.005111 -0.000146
# 2            DummyRegressor  0.002817   0.003027 -0.001737
# 3            DummyRegressor       0.0   0.005926 -0.000101
# 4            DummyRegressor       0.0        0.0 -0.000114
# 5          LinearRegression  0.032519   0.036603  0.682162
# 6          LinearRegression  0.040433   0.015598   0.66999
# 7          LinearRegression  0.022859   0.008317  0.649247
# 8          LinearRegression  0.024487   0.024637  0.669873
# 9          LinearRegression  0.018685   0.017441  0.669023
# 10  LinearRegression_target   0.06676   0.014563  0.684232
# 11  LinearRegression_target  0.066108        0.0  0.671042
# 12  LinearRegression_target  0.075596   0.009121  0.646094
# 13  LinearRegression_target  0.047379   0.017445  0.677544
# 14  LinearRegression_target  0.060982   0.021015  0.677014
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.008004
# 1                 -75787.787194                    -95217.629397     0.010003
# 2                 -76753.598961                    -96253.253947     0.005844
# 3                 -76837.804811                    -95983.885799     0.005926
# 4                 -76617.245449                    -96182.764729          0.0
# 5                 -39855.690921                    -54254.958115     0.069122
# 6                 -40272.565406                    -54695.230224     0.056031
# 7                 -42178.059246                    -56955.988686     0.031176
# 8                 -40806.492452                     -55146.31876     0.049124
# 9                 -40788.496555                    -55331.351171     0.036126
# 10                -38127.990089                     -54078.01827     0.081323
# 11                -38515.387176                    -54607.941381     0.066108
# 12                -40531.127384                    -57211.351394     0.084717
# 13                -38827.012941                    -54501.880328     0.064824
# 14                -38544.774193                    -54659.330513     0.081997

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.001542   0.004414 -0.000436
# LinearRegression         0.027797   0.020519  0.668059
# LinearRegression_target  0.063365   0.012429  0.671185
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                       -40780.260916
# LinearRegression_target                -38909.258356
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.005955
# LinearRegression                           -55276.769391     0.048316
# LinearRegression_target                    -55011.704377     0.075794

# %%
plot_comparar_metricas_modelos(df_resultados)

# %% [markdown]
# - Tempo: transformador de target do LinearRegression leva 2x mais que só o LinearRegression
# - R2, MAE e RMSE: teve pequenas melhorias do LinearRegression com TargetTransformer em relação ao LinearRegression
# - Usando ambos os modelos de LinearRegression é melhor que usar o DummyRegression (chutando a média)

# %% [markdown]
# ### Avaliando a transformação de target

# %%
param_grid = {
    "transformer": [
        None,
        PowerTransformer(),
        QuantileTransformer(output_distribution="normal"),
    ]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(), 
    preprocessor=preprocessamento,
    target_transformer=target_transformer,
    param_grid=param_grid
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot_encoder',
#                                                                                                               OneHotEncoder(),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'transformer': QuantileTransformer(output_distribution='normal')}

# %% [markdown]
# QuantileTransformer apresentou melhor parâmetro de transformador que o PowerTransformer

# %%
grid_search.best_score_
# Out:
# np.float64(-54417.87027091748)

# %% [markdown]
# - QuantileTransformer: -54411
# - PowerTransformer: -55017
# - Obs: quanto mais próximo de 0, melhor

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                              coeficiente
# remainder__longitude                           -0.295623
# remainder__latitude                            -0.289131
# remainder__population_per_household            -0.280467
# one_hot_encoder__ocean_proximity_INLAND        -0.277218
# one_hot_encoder__ocean_proximity_NEAR BAY      -0.022367
# remainder__total_bedrooms                      -0.000227
# remainder__total_rooms                         -0.000061
# remainder__population                          -0.000034
# remainder__households                           0.000856
# remainder__housing_median_age                   0.006584
# ordinal_encoder__median_income_cat              0.035922
# remainder__rooms_per_household                  0.118101
# one_hot_encoder__ocean_proximity_NEAR OCEAN     0.119421
# one_hot_encoder__ocean_proximity_<1H OCEAN      0.180164
# remainder__median_income                        0.385892
# remainder__bedrooms_per_room                    3.928835

# %%
plot_coeficientes(coefs)

# %% [markdown]
# A coluna bedrooms_per_room possui mais relevância pra coluna target (median_house_value)

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target_power": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
    "LinearRegression_target_quantile": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                                model  fit_time score_time   test_r2  \
# 0                     DummyRegressor  0.018311   0.002488 -0.000081
# 1                     DummyRegressor       0.0   0.009541 -0.000146
# 2                     DummyRegressor  0.002811        0.0 -0.001737
# 3                     DummyRegressor       0.0        0.0 -0.000101
# 4                     DummyRegressor       0.0   0.013048 -0.000114
# 5                   LinearRegression  0.037769   0.010002  0.682162
# 6                   LinearRegression  0.032666   0.014578   0.66999
# 7                   LinearRegression  0.028659   0.003009  0.649247
# 8                   LinearRegression  0.026873   0.005008  0.669873
# 9                   LinearRegression  0.045755   0.013507  0.669023
# 10     LinearRegression_target_power  0.069468   0.013047  0.684232
# 11     LinearRegression_target_power  0.077067   0.015628  0.671042
# 12     LinearRegression_target_power  0.047615   0.015734  0.646094
# 13     LinearRegression_target_power  0.063029   0.030647  0.677544
# 14     LinearRegression_target_power  0.053111   0.040792  0.677014
# 15  LinearRegression_target_quantile  0.039002   0.015621  0.692383
# 16  LinearRegression_target_quantile  0.032241   0.014194  0.678355
# 17  LinearRegression_target_quantile  0.051611   0.011539  0.653251
# 18  LinearRegression_target_quantile  0.031251   0.021734  0.683764
# 19  LinearRegression_target_quantile  0.015625   0.015621  0.682954
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.020799
# 1                 -75787.787194                    -95217.629397     0.009541
# 2                 -76753.598961                    -96253.253947     0.002811
# 3                 -76837.804811                    -95983.885799          0.0
# 4                 -76617.245449                    -96182.764729     0.013048
# 5                 -39855.690921                    -54254.958115     0.047771
# 6                 -40272.565406                    -54695.230224     0.047245
# 7                 -42178.059246                    -56955.988686     0.031668
# 8                 -40806.492452                     -55146.31876     0.031882
# 9                 -40788.496555                    -55331.351171     0.059263
# 10                -38127.990089                     -54078.01827     0.082514
# 11                -38515.387176                    -54607.941381     0.092695
# 12                -40531.127384                    -57211.351394     0.063349
# 13                -38827.012941                    -54501.880328     0.093675
# 14                -38544.774193                    -54659.330513     0.093903
# 15                -37787.811519                    -53375.451587     0.054624
# 16                -38295.451002                    -53997.574535     0.046435
# 17                -40304.141083                    -56629.921941      0.06315
# 18                -38595.844694                    -53973.630723     0.052985
# 19                -38404.116643                    -54154.399672     0.031247

# %%
df_resultados.groupby("model").mean()
# Out:
#                                   fit_time score_time   test_r2  \
# model
# DummyRegressor                    0.004224   0.005015 -0.000436
# LinearRegression                  0.034344   0.009221  0.668059
# LinearRegression_target_power     0.062058   0.023169  0.671185
# LinearRegression_target_quantile  0.033946   0.015742  0.678142
#
#                                  test_neg_mean_absolute_error  \
# model
# DummyRegressor                                  -76702.495836
# LinearRegression                                -40780.260916
# LinearRegression_target_power                   -38909.258356
# LinearRegression_target_quantile                -38677.472988
#
#                                  test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                      -95975.447913      0.00924
# LinearRegression                                    -55276.769391     0.043565
# LinearRegression_target_power                       -55011.704377     0.085227
# LinearRegression_target_quantile                    -54426.195692     0.049688

# %%
plot_comparar_metricas_modelos(df_resultados)

# %% [markdown]
# - Tempo: com a transformação de target o QuantileTransformer é mais rápida que PowerTransformer
# - R2, MAE, RMSE: QuantileTransformer melhora um pouco as métricas que o PowerTransformer
# - É melhor usar o transformador de target do QuantileTransformer que o PowerTransformer

# %%
# Plota gráfico de resíduos com melhor modelo, usando 10% dos dados e com formatação de abreviação dos números
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)

# %% [markdown]
# Pegando 10% dos dados e comparando os dados reais com os dados do melhor estimador de modelo (QuantileTransformer):
# - Percebe-se que uma parte significativa dos pontos estão próximos da reta no gráfico de resíduos (2), fazendo que o modelo tenha menos erros
# - Possue mais erros positivos que negativos, sendo observado tanto pelo histograma (1) com a cauda mais alongada para os valores positivos e o gráfico de dispersão de resíduos (2) com mais valores acima da reta que abaixo da reta
